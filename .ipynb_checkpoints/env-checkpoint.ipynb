# %%
# !pip install torch numpy networkx matplotlib gym pygraphviz stable-baselines3
# Out:
# Requirement already satisfied: torch in /opt/anaconda3/lib/python3.11/site-packages (2.10.0)
# Requirement already satisfied: numpy in /opt/anaconda3/lib/python3.11/site-packages (1.26.4)
# Requirement already satisfied: networkx in /opt/anaconda3/lib/python3.11/site-packages (3.1)
# Requirement already satisfied: matplotlib in /opt/anaconda3/lib/python3.11/site-packages (3.10.6)
# Requirement already satisfied: gym in /opt/anaconda3/lib/python3.11/site-packages (0.26.2)
# Requirement already satisfied: pygraphviz in /opt/anaconda3/lib/python3.11/site-packages (1.14)
# Requirement already satisfied: stable-baselines3 in /opt/anaconda3/lib/python3.11/site-packages (2.7.1)
# Requirement already satisfied: filelock in /opt/anaconda3/lib/python3.11/site-packages (from torch) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in /opt/anaconda3/lib/python3.11/site-packages (from torch) (4.15.0)
# Requirement already satisfied: sympy>=1.13.3 in /opt/anaconda3/lib/python3.11/site-packages (from torch) (1.14.0)
# Requirement already satisfied: jinja2 in /opt/anaconda3/lib/python3.11/site-packages (from torch) (3.1.3)
# Requirement already satisfied: fsspec>=0.8.5 in /opt/anaconda3/lib/python3.11/site-packages (from torch) (2023.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/anaconda3/lib/python3.11/site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /opt/anaconda3/lib/python3.11/site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/anaconda3/lib/python3.11/site-packages (from matplotlib) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/anaconda3/lib/python3.11/site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /opt/anaconda3/lib/python3.11/site-packages (from matplotlib) (23.1)
# Requirement already satisfied: pillow>=8 in /opt/anaconda3/lib/python3.11/site-packages (from matplotlib) (10.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/anaconda3/lib/python3.11/site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/anaconda3/lib/python3.11/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: cloudpickle>=1.2.0 in /opt/anaconda3/lib/python3.11/site-packages (from gym) (2.2.1)
# Requirement already satisfied: gym_notices>=0.0.4 in /opt/anaconda3/lib/python3.11/site-packages (from gym) (0.1.0)
# Requirement already satisfied: gymnasium<1.3.0,>=0.29.1 in /opt/anaconda3/lib/python3.11/site-packages (from stable-baselines3) (0.29.1)
# Requirement already satisfied: pandas in /opt/anaconda3/lib/python3.11/site-packages (from stable-baselines3) (2.1.4)
# Requirement already satisfied: farama-notifications>=0.0.1 in /opt/anaconda3/lib/python3.11/site-packages (from gymnasium<1.3.0,>=0.29.1->stable-baselines3) (0.0.4)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/anaconda3/lib/python3.11/site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/anaconda3/lib/python3.11/site-packages (from jinja2->torch) (2.1.3)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/lib/python3.11/site-packages (from pandas->stable-baselines3) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /opt/anaconda3/lib/python3.11/site-packages (from pandas->stable-baselines3) (2023.3)

# %%
# !pip install pydot
# Out:
# Requirement already satisfied: pydot in /opt/anaconda3/lib/python3.11/site-packages (4.0.1)
# Requirement already satisfied: pyparsing>=3.1.0 in /opt/anaconda3/lib/python3.11/site-packages (from pydot) (3.3.2)

# %%
import gymnasium as gym
import numpy as np
import networkx as nx
import torch
import matplotlib.pyplot as plt
import os
import random
from gymnasium import spaces
from xing import XingLoss

# %% [markdown]
# ## define the env

# %%
MAX_NODES = 100

class GraphLayoutEnv(gym.Env):
    def __init__(self, G, max_steps=200, move_penalty=0.001):
        super(GraphLayoutEnv, self).__init__()
        
        self.G = G
        self.n_nodes = G.number_of_nodes()
        self.max_steps = max_steps
        self.move_penalty = move_penalty
        
        self.xing_loss = XingLoss(G, soft=False)
        
        self.action_space = spaces.Box(
            low=np.array([-1.0, -1.0, -1.0]),
            high=np.array([1.0, 1.0, 1.0]),
            dtype=np.float32
        )
        
        self.observation_space = spaces.Box(
            low=-np.inf,
            high=np.inf,
            shape=(self.n_nodes * 2 + 1,),
            dtype=np.float32
        )
        
        self.initial_pos = nx.spring_layout(G, seed=42)
        self.coords = None
        self.current_crossings = None
        self.steps = 0
        self.no_improve_steps = 0
        
    def _pos_to_coords(self, pos):
        nodes = list(self.G.nodes())
        coords = np.array([[pos[v][0], pos[v][1]] for v in nodes], 
                          dtype=np.float32)
        return coords
    
    def _normalize_coords(self, coords):
        min_val = coords.min()
        max_val = coords.max()
        if max_val - min_val < 1e-6:
            return coords
        return 2 * (coords - min_val) / (max_val - min_val) - 1
    
    def _get_obs(self):
        coords_norm = self._normalize_coords(self.coords)
        coords_flat = coords_norm.flatten()
        max_possible_crossings = self.G.number_of_edges() ** 2
        crossings_norm = self.current_crossings / (max_possible_crossings + 1e-6)
        obs = np.append(coords_flat, crossings_norm).astype(np.float32)
        return obs
    
    def _compute_crossings(self, coords):
        coords_tensor = torch.tensor(coords, dtype=torch.float32)
        with torch.no_grad():
            crossings = self.xing_loss(coords_tensor).item()
        return crossings
    
    def reset(self, seed=None, options=None):
        super().reset(seed=seed)
        # todo: multi-start
        # neato
        
        # 每次reset随机选一张图
        graph_path = random.choice(self.graph_paths)
        self.G = nx.read_graphml(graph_path)
        self.G = nx.convert_node_labels_to_integers(self.G, ordering="sorted")
        self.n_nodes = self.G.number_of_nodes()
        self.xing_loss = XingLoss(self.G, soft=False)
        
        # 用neato生成初始布局
        pos = nx.nx_agraph.graphviz_layout(self.G, prog="neato")
        self.coords = self._pos_to_coords(pos)
        self.current_crossings = self._compute_crossings(self.coords)
        self.steps = 0
        self.no_improve_steps = 0
        return self._get_obs(), {}
    
    def step(self, action):
        node_idx = int((action[0] + 1) / 2 * self.n_nodes)
        node_idx = np.clip(node_idx, 0, self.n_nodes - 1)
        delta_x = action[1] * 50
        delta_y = action[2] * 50
        
        old_crossings = self.current_crossings
        
        new_coords = self.coords.copy()
        new_coords[node_idx, 0] += delta_x
        new_coords[node_idx, 1] += delta_y
        
        new_crossings = self._compute_crossings(new_coords)
        
        crossing_improvement = old_crossings - new_crossings
        move_distance = np.sqrt(delta_x**2 + delta_y**2)
        reward = crossing_improvement * 10 - self.move_penalty * move_distance
        
        self.coords = new_coords
        self.current_crossings = new_crossings
        self.steps += 1
        
        if crossing_improvement <= 0:
            self.no_improve_steps += 1
        else:
            self.no_improve_steps = 0
            
        terminated = bool(self.current_crossings == 0)
        truncated = bool(
            self.steps >= self.max_steps or
            self.no_improve_steps >= 20
        )
        
        info = {
            "crossings": self.current_crossings,
            "crossing_improvement": crossing_improvement,
            "steps": self.steps
        }
        
        return self._get_obs(), reward, terminated, truncated, info

    def get_neato_coords(G):
        pos = nx.nx_agraph.graphviz_layout(G, prog="neato")
        coords = torch.tensor(
            [[pos[v][0], pos[v][1]] for v in G.nodes()],
            dtype=torch.float32,
        )
        return pos, coords
    
    def render(self):
        nodes = list(self.G.nodes())
        pos = {nodes[i]: (self.coords[i, 0], self.coords[i, 1]) 
               for i in range(self.n_nodes)}
        plt.figure(figsize=(6, 6))
        nx.draw(self.G, pos, with_labels=False, 
                node_size=30, node_color='lightblue', edge_color='gray')
        plt.title(f"Crossings: {int(self.current_crossings)}")
        plt.show()

# %%
rome_dir = "/Users/apple/Desktop/cs5180 Reinforcement Learning/project/cs5180/rome"
train_graphs = []
for fname in os.listdir(rome_dir):
    if not fname.endswith(".graphml"):
        continue
    try:
        graph_num = int(fname.split("grafo")[1].split(".")[0])
    except:
        continue
    if graph_num > 9999:
        continue
    fpath = os.path.join(rome_dir, fname)
    G_tmp = nx.read_graphml(fpath)
    if G_tmp.number_of_nodes() <= MAX_NODES:
        train_graphs.append(fpath)

print(f"Total training graphs: {len(train_graphs)}")
# Out:
# Total training graphs: 9872

# %%
env = GraphLayoutEnv(G, max_steps=100)
obs, info = env.reset()

print("Observation shape:", obs.shape)
print("Initial crossings:", env.current_crossings)
env.render()
# Out:
# Observation shape: (125,)
# Initial crossings: 71.0

# %%
crossing_history = [env.current_crossings]

obs, _ = env.reset()
for i in range(50):
    action = env.action_space.sample()
    obs, reward, terminated, truncated, info = env.step(action)
    crossing_history.append(info['crossings'])
    if terminated or truncated:
        print(f"Episode ends, in total {i+1} steps")
        break

print(f"Initial crossing: {crossing_history[0]}")
print(f"Final crossing: {crossing_history[-1]}")
# Out:
# Initial crossing: 71.0
# Final crossing: 507.0

# %%
plt.figure(figsize=(8, 4))
plt.plot(crossing_history)
plt.xlabel("Steps")
plt.ylabel("Edge Crossings")
plt.title("The number of Crossings (Random Policy)")
plt.grid(True)
plt.show()

# %% [markdown]
# ## PPO

# %%
# !pip install stable-baselines3
# Out:
# Requirement already satisfied: stable-baselines3 in /opt/anaconda3/lib/python3.11/site-packages (2.7.1)
# Requirement already satisfied: gymnasium<1.3.0,>=0.29.1 in /opt/anaconda3/lib/python3.11/site-packages (from stable-baselines3) (0.29.1)
# Requirement already satisfied: numpy<3.0,>=1.20 in /opt/anaconda3/lib/python3.11/site-packages (from stable-baselines3) (1.26.4)
# Requirement already satisfied: torch<3.0,>=2.3 in /opt/anaconda3/lib/python3.11/site-packages (from stable-baselines3) (2.10.0)
# Requirement already satisfied: cloudpickle in /opt/anaconda3/lib/python3.11/site-packages (from stable-baselines3) (2.2.1)
# Requirement already satisfied: pandas in /opt/anaconda3/lib/python3.11/site-packages (from stable-baselines3) (2.1.4)
# Requirement already satisfied: matplotlib in /opt/anaconda3/lib/python3.11/site-packages (from stable-baselines3) (3.10.6)
# Requirement already satisfied: typing-extensions>=4.3.0 in /opt/anaconda3/lib/python3.11/site-packages (from gymnasium<1.3.0,>=0.29.1->stable-baselines3) (4.15.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /opt/anaconda3/lib/python3.11/site-packages (from gymnasium<1.3.0,>=0.29.1->stable-baselines3) (0.0.4)
# Requirement already satisfied: filelock in /opt/anaconda3/lib/python3.11/site-packages (from torch<3.0,>=2.3->stable-baselines3) (3.13.1)
# Requirement already satisfied: sympy>=1.13.3 in /opt/anaconda3/lib/python3.11/site-packages (from torch<3.0,>=2.3->stable-baselines3) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /opt/anaconda3/lib/python3.11/site-packages (from torch<3.0,>=2.3->stable-baselines3) (3.1)
# Requirement already satisfied: jinja2 in /opt/anaconda3/lib/python3.11/site-packages (from torch<3.0,>=2.3->stable-baselines3) (3.1.3)
# Requirement already satisfied: fsspec>=0.8.5 in /opt/anaconda3/lib/python3.11/site-packages (from torch<3.0,>=2.3->stable-baselines3) (2023.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/anaconda3/lib/python3.11/site-packages (from matplotlib->stable-baselines3) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /opt/anaconda3/lib/python3.11/site-packages (from matplotlib->stable-baselines3) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/anaconda3/lib/python3.11/site-packages (from matplotlib->stable-baselines3) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/anaconda3/lib/python3.11/site-packages (from matplotlib->stable-baselines3) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /opt/anaconda3/lib/python3.11/site-packages (from matplotlib->stable-baselines3) (23.1)
# Requirement already satisfied: pillow>=8 in /opt/anaconda3/lib/python3.11/site-packages (from matplotlib->stable-baselines3) (10.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/anaconda3/lib/python3.11/site-packages (from matplotlib->stable-baselines3) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/anaconda3/lib/python3.11/site-packages (from matplotlib->stable-baselines3) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/lib/python3.11/site-packages (from pandas->stable-baselines3) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /opt/anaconda3/lib/python3.11/site-packages (from pandas->stable-baselines3) (2023.3)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib->stable-baselines3) (1.16.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/anaconda3/lib/python3.11/site-packages (from sympy>=1.13.3->torch<3.0,>=2.3->stable-baselines3) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/anaconda3/lib/python3.11/site-packages (from jinja2->torch<3.0,>=2.3->stable-baselines3) (2.1.3)

# %%
from stable_baselines3 import PPO
from stable_baselines3.common.env_checker import check_env

# 创建环境
env = GraphLayoutEnv(train_graphs, max_steps=500, move_penalty=0.001)

# 检查环境
check_env(env)
print("Environment check passed!")

# 训练PPO
model = PPO(
    "MlpPolicy",
    env,
    verbose=1,
    learning_rate=3e-4,
    n_steps=1024,
    batch_size=64,
    n_epochs=10,
)

model.learn(total_timesteps=500000)
model.save("ppo_graph_layout")
print("Training done!")
# Out:
# Gym has been unmaintained since 2022 and does not support NumPy 2.0 amongst other critical functionality.
# Please upgrade to Gymnasium, the maintained drop-in replacement of Gym, or contact the authors of your software and request that they upgrade.
# Users of this version of Gym should be able to simply replace 'import gym' with 'import gymnasium as gym' in the vast majority of cases.
# See the migration guide at https://gymnasium.farama.org/introduction/migration_guide/ for additional information.
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[16], line 5
#       2 from stable_baselines3.common.env_checker import check_env
#       4 # 创建环境
# ----> 5 env = GraphLayoutEnv(train_graphs, max_steps=500, move_penalty=0.001)
#       7 # 检查环境
#       8 check_env(env)
#
# Cell In[14], line 8, in GraphLayoutEnv.__init__(self, G, max_steps, move_penalty)
#       5 super(GraphLayoutEnv, self).__init__()
#       7 self.G = G
# ----> 8 self.n_nodes = G.number_of_nodes()
#       9 self.max_steps = max_steps
#      10 self.move_penalty = move_penalty
#
# AttributeError: 'list' object has no attribute 'number_of_nodes'

# %%
# Create env
env = GraphLayoutEnv(G, max_steps=500, move_penalty=0.001)

# add training steps
model = PPO(
    "MlpPolicy",
    env,
    verbose=1,
    learning_rate=3e-4,
    n_steps=1024,
    batch_size=64,
    n_epochs=10,
)

model.learn(total_timesteps=200000)
print("Training done!")
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 500      |
# |    ep_rew_mean     | -8.1e+03 |
# | time/              |          |
# |    fps             | 991      |
# |    iterations      | 1        |
# |    time_elapsed    | 1        |
# |    total_timesteps | 1024     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 500         |
# |    ep_rew_mean          | -7.85e+03   |
# | time/                   |             |
# |    fps                  | 919         |
# |    iterations           | 2           |
# |    time_elapsed         | 2           |
# |    total_timesteps      | 2048        |
# | train/                  |             |
# |    approx_kl            | 0.005437956 |
# |    clip_fraction        | 0.0305      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.27       |
# |    explained_variance   | -0.000193   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.82e+04    |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.01       |
# |    std                  | 1.01        |
# |    value_loss           | 3.24e+05    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 500          |
# |    ep_rew_mean          | -7.44e+03    |
# | time/                   |              |
# |    fps                  | 896          |
# |    iterations           | 3            |
# |    time_elapsed         | 3            |
# |    total_timesteps      | 3072         |
# | train/                  |              |
# |    approx_kl            | 0.0034612324 |
# |    clip_fraction        | 0.00547      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.28        |
# |    explained_variance   | -0.000484    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.67e+05     |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.00464     |
# |    std                  | 1.01         |
# |    value_loss           | 3.48e+05     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 500          |
# |    ep_rew_mean          | -7.53e+03    |
# | time/                   |              |
# |    fps                  | 889          |
# |    iterations           | 4            |
# |    time_elapsed         | 4            |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0033025197 |
# |    clip_fraction        | 0.00518      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.27        |
# |    explained_variance   | -0.00794     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.04e+05     |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.00652     |
# |    std                  | 1            |
# |    value_loss           | 2.42e+05     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 500          |
# |    ep_rew_mean          | -7.5e+03     |
# | time/                   |              |
# |    fps                  | 881          |
# |    iterations           | 5            |
# |    time_elapsed         | 5            |
# |    total_timesteps      | 5120         |
# | train/                  |              |
# |    approx_kl            | 0.0021852194 |
# |    clip_fraction        | 0.00342      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.27        |
# |    explained_variance   | -0.00373     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.08e+05     |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.00463     |
# |    std                  | 1            |
# |    value_loss           | 2.54e+05     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 500         |
# |    ep_rew_mean          | -7.27e+03   |
# | time/                   |             |
# |    fps                  | 877         |
# |    iterations           | 6           |
# |    time_elapsed         | 7           |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.005728068 |
# |    clip_fraction        | 0.0292      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.27       |
# |    explained_variance   | -0.00324    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.27e+05    |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.00799    |
# |    std                  | 1           |
# |    value_loss           | 2.77e+05    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 500          |
# |    ep_rew_mean          | -7.24e+03    |
# | time/                   |              |
# |    fps                  | 875          |
# |    iterations           | 7            |
# |    time_elapsed         | 8            |
# |    total_timesteps      | 7168         |
# | train/                  |              |
# |    approx_kl            | 0.0055143405 |
# |    clip_fraction        | 0.034        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.28        |
# |    explained_variance   | -0.00224     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.63e+05     |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -0.00613     |
# |    std                  | 1.01         |
# |    value_loss           | 2.75e+05     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 500         |
# |    ep_rew_mean          | -7.22e+03   |
# | time/                   |             |
# |    fps                  | 873         |
# |    iterations           | 8           |
# |    time_elapsed         | 9           |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.004787012 |
# |    clip_fraction        | 0.0227      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.27       |
# |    explained_variance   | 0.00955     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 9.02e+04    |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.00638    |
# |    std                  | 1           |
# |    value_loss           | 2.07e+05    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 500          |
# |    ep_rew_mean          | -7.28e+03    |
# | time/                   |              |
# |    fps                  | 871          |
# |    iterations           | 9            |
# |    time_elapsed         | 10           |
# |    total_timesteps      | 9216         |
# | train/                  |              |
# |    approx_kl            | 0.0015142828 |
# |    clip_fraction        | 0.000293     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.26        |
# |    explained_variance   | 0.0118       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.95e+05     |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.00296     |
# |    std                  | 1            |
# |    value_loss           | 2.91e+05     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 500         |
# |    ep_rew_mean          | -7.26e+03   |
# | time/                   |             |
# |    fps                  | 871         |
# |    iterations           | 10          |
# |    time_elapsed         | 11          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.004334413 |
# |    clip_fraction        | 0.0121      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.26       |
# |    explained_variance   | 0.0127      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.46e+05    |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.00519    |
# |    std                  | 1           |
# |    value_loss           | 2.96e+05    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 500          |
# |    ep_rew_mean          | -7.26e+03    |
# | time/                   |              |
# |    fps                  | 866          |
# |    iterations           | 11           |
# |    time_elapsed         | 12           |
# |    total_timesteps      | 11264        |
# | train/                  |              |
# |    approx_kl            | 0.0051326305 |
# |    clip_fraction        | 0.0267       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.26        |
# |    explained_variance   | -0.00208     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.5e+05      |
# |    n_updates            | 100          |
# |    policy_gradient_loss | -0.0057      |
# |    std                  | 0.998        |
# |    value_loss           | 2.82e+05     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 500         |
# |    ep_rew_mean          | -7.31e+03   |
# | time/                   |             |
# |    fps                  | 865         |
# |    iterations           | 12          |
# |    time_elapsed         | 14          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.005260572 |
# |    clip_fraction        | 0.0266      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.25       |
# |    explained_variance   | -0.00853    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 9.64e+04    |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.00679    |
# |    std                  | 0.998       |
# |    value_loss           | 2.16e+05    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 500         |
# |    ep_rew_mean          | -7.37e+03   |
# | time/                   |             |
# |    fps                  | 863         |
# |    iterations           | 13          |
# |    time_elapsed         | 15          |
# |    total_timesteps      | 13312       |
# | train/                  |             |
# |    approx_kl            | 0.004492021 |
# |    clip_fraction        | 0.0221      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.25       |
# |    explained_variance   | 0.0338      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.16e+05    |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.0043     |
# |    std                  | 0.996       |
# |    value_loss           | 1.89e+05    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 500         |
# |    ep_rew_mean          | -7.41e+03   |
# | time/                   |             |
# |    fps                  | 860         |
# |    iterations           | 14          |
# |    time_elapsed         | 16          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.005647938 |
# |    clip_fraction        | 0.0267      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.24       |
# |    explained_variance   | 0.00262     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.18e+05    |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.00753    |
# |    std                  | 0.995       |
# |    value_loss           | 2.66e+05    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 500         |
# |    ep_rew_mean          | -7.43e+03   |
# | time/                   |             |
# |    fps                  | 860         |
# |    iterations           | 15          |
# |    time_elapsed         | 17          |
# |    total_timesteps      | 15360       |
# | train/                  |             |
# |    approx_kl            | 0.005404805 |
# |    clip_fraction        | 0.0331      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.26       |
# |    explained_variance   | 0.00012     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.06e+05    |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.00658    |
# |    std                  | 1.01        |
# |    value_loss           | 2.26e+05    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 500          |
# |    ep_rew_mean          | -7.5e+03     |
# | time/                   |              |
# |    fps                  | 860          |
# |    iterations           | 16           |
# |    time_elapsed         | 19           |
# |    total_timesteps      | 16384        |
# | train/                  |              |
# |    approx_kl            | 0.0018942389 |
# |    clip_fraction        | 0.000391     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.28        |
# |    explained_variance   | 0.0447       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.12e+05     |
# |    n_updates            | 150          |
# |    policy_gradient_loss | -0.0031      |
# |    std                  | 1.01         |
# |    value_loss           | 2.78e+05     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 500          |
# |    ep_rew_mean          | -7.51e+03    |
# | time/                   |              |
# |    fps                  | 859          |
# |    iterations           | 17           |
# |    time_elapsed         | 20           |
# |    total_timesteps      | 17408        |
# | train/                  |              |
# |    approx_kl            | 0.0068516424 |
# |    clip_fraction        | 0.035        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.27        |
# |    explained_variance   | 0.000851     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.13e+05     |
# |    n_updates            | 160          |
# |    policy_gradient_loss | -0.00778     |
# |    std                  | 1            |
# |    value_loss           | 2.66e+05     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 500          |
# |    ep_rew_mean          | -7.48e+03    |
# | time/                   |              |
# |    fps                  | 859          |
# |    iterations           | 18           |
# |    time_elapsed         | 21           |
# |    total_timesteps      | 18432        |
# | train/                  |              |
# |    approx_kl            | 0.0036391031 |
# |    clip_fraction        | 0.0338       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.27        |
# |    explained_variance   | -0.00143     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.78e+05     |
# |    n_updates            | 170          |
# |    policy_gradient_loss | -0.00457     |
# |    std                  | 1.01         |
# |    value_loss           | 2.33e+05     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 500          |
# |    ep_rew_mean          | -7.52e+03    |
# | time/                   |              |
# |    fps                  | 855          |
# |    iterations           | 19           |
# |    time_elapsed         | 22           |
# |    total_timesteps      | 19456        |
# | train/                  |              |
# |    approx_kl            | 0.0060344674 |
# |    clip_fraction        | 0.0445       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.27        |
# |    explained_variance   | 0.00703      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.49e+05     |
# |    n_updates            | 180          |
# |    policy_gradient_loss | -0.00636     |
# |    std                  | 1            |
# |    value_loss           | 2.79e+05     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 500         |
# |    ep_rew_mean          | -7.52e+03   |
# | time/                   |             |
# |    fps                  | 855         |
# |    iterations           | 20          |
# |    time_elapsed         | 23          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.005400128 |
# |    clip_fraction        | 0.0411      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.26       |
# |    explained_variance   | 0.00523     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 9.38e+04    |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.00549    |
# |    std                  | 1           |
# |    value_loss           | 2.07e+05    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 500          |
# |    ep_rew_mean          | -7.49e+03    |
# | time/                   |              |
# |    fps                  | 854          |
# |    iterations           | 21           |
# |    time_elapsed         | 25           |
# |    total_timesteps      | 21504        |
# | train/                  |              |
# |    approx_kl            | 0.0048117135 |
# |    clip_fraction        | 0.017        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.27        |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.44e+05     |
# |    n_updates            | 200          |
# |    policy_gradient_loss | -0.00684     |
# |    std                  | 1.01         |
# |    value_loss           | 2.48e+05     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 500         |
# |    ep_rew_mean          | -7.44e+03   |
# | time/                   |             |
# |    fps                  | 854         |
# |    iterations           | 22          |
# |    time_elapsed         | 26          |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.002969936 |
# |    clip_fraction        | 0.00508     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.28       |
# |    explained_variance   | -0.00249    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.12e+05    |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.00229    |
# |    std                  | 1.01        |
# |    value_loss           | 2.09e+05    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 500          |
# |    ep_rew_mean          | -7.47e+03    |
# | time/                   |              |
# |    fps                  | 854          |
# |    iterations           | 23           |
# |    time_elapsed         | 27           |
# |    total_timesteps      | 23552        |
# | train/                  |              |
# |    approx_kl            | 0.0066963034 |
# |    clip_fraction        | 0.0531       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.28        |
# |    explained_variance   | -0.000171    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.23e+05     |
# |    n_updates            | 220          |
# |    policy_gradient_loss | -0.0105      |
# |    std                  | 1.01         |
# |    value_loss           | 2.36e+05     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 500          |
# |    ep_rew_mean          | -7.47e+03    |
# | time/                   |              |
# |    fps                  | 854          |
# |    iterations           | 24           |
# |    time_elapsed         | 28           |
# |    total_timesteps      | 24576        |
# | train/                  |              |
# |    approx_kl            | 0.0070054843 |
# |    clip_fraction        | 0.0538       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.29        |
# |    explained_variance   | 9.83e-05     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.92e+05     |
# |    n_updates            | 230          |
# |    policy_gradient_loss | -0.00899     |
# |    std                  | 1.01         |
# |    value_loss           | 2.7e+05      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 500         |
# |    ep_rew_mean          | -7.47e+03   |
# | time/                   |             |
# |    fps                  | 854         |
# |    iterations           | 25          |
# |    time_elapsed         | 29          |
# |    total_timesteps      | 25600       |
# | train/                  |             |
# |    approx_kl            | 0.004857799 |
# |    clip_fraction        | 0.0346      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.31       |
# |    explained_variance   | -0.000224   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.56e+05    |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.00508    |
# |    std                  | 1.02        |
# |    value_loss           | 2.67e+05    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 500          |
# |    ep_rew_mean          | -7.5e+03     |
# | time/                   |              |
# |    fps                  | 853          |
# |    iterations           | 26           |
# |    time_elapsed         | 31           |
# |    total_timesteps      | 26624        |
# | train/                  |              |
# |    approx_kl            | 0.0059932997 |
# |    clip_fraction        | 0.0362       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.31        |
# |    explained_variance   | 5.14e-05     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.22e+05     |
# |    n_updates            | 250          |
# |    policy_gradient_loss | -0.00707     |
# |    std                  | 1.02         |
# |    value_loss           | 2.65e+05     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 500          |
# |    ep_rew_mean          | -7.47e+03    |
# | time/                   |              |
# |    fps                  | 853          |
# |    iterations           | 27           |
# |    time_elapsed         | 32           |
# |    total_timesteps      | 27648        |
# | train/                  |              |
# |    approx_kl            | 0.0019121257 |
# |    clip_fraction        | 0.00215      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.32        |
# |    explained_variance   | -0.00016     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.61e+05     |
# |    n_updates            | 260          |
# |    policy_gradient_loss | -0.00266     |
# |    std                  | 1.03         |
# |    value_loss           | 3.34e+05     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 500         |
# |    ep_rew_mean          | -7.49e+03   |
# | time/                   |             |
# |    fps                  | 854         |
# |    iterations           | 28          |
# |    time_elapsed         | 33          |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.004246882 |
# |    clip_fraction        | 0.0351      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.33       |
# |    explained_variance   | -4.64e-05   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 9.29e+04    |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.00529    |
# |    std                  | 1.02        |
# |    value_loss           | 2.24e+05    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 500          |
# |    ep_rew_mean          | -7.49e+03    |
# | time/                   |              |
# |    fps                  | 854          |
# |    iterations           | 29           |
# |    time_elapsed         | 34           |
# |    total_timesteps      | 29696        |
# | train/                  |              |
# |    approx_kl            | 0.0043355664 |
# |    clip_fraction        | 0.0153       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.33        |
# |    explained_variance   | -0.000286    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.95e+05     |
# |    n_updates            | 280          |
# |    policy_gradient_loss | -0.00663     |
# |    std                  | 1.02         |
# |    value_loss           | 3.15e+05     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 500          |
# |    ep_rew_mean          | -7.47e+03    |
# | time/                   |              |
# |    fps                  | 854          |
# |    iterations           | 30           |
# |    time_elapsed         | 35           |
# |    total_timesteps      | 30720        |
# | train/                  |              |
# |    approx_kl            | 0.0067623397 |
# |    clip_fraction        | 0.0304       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.33        |
# |    explained_variance   | -0.0109      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 8.63e+04     |
# |    n_updates            | 290          |
# |    policy_gradient_loss | -0.00623     |
# |    std                  | 1.02         |
# |    value_loss           | 2.18e+05     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 500          |
# |    ep_rew_mean          | -7.46e+03    |
# | time/                   |              |
# |    fps                  | 854          |
# |    iterations           | 31           |
# |    time_elapsed         | 37           |
# |    total_timesteps      | 31744        |
# | train/                  |              |
# |    approx_kl            | 0.0048832414 |
# |    clip_fraction        | 0.044        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.32        |
# |    explained_variance   | -2.53e-05    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.44e+05     |
# |    n_updates            | 300          |
# |    policy_gradient_loss | -0.00967     |
# |    std                  | 1.02         |
# |    value_loss           | 2.38e+05     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 500         |
# |    ep_rew_mean          | -7.48e+03   |
# | time/                   |             |
# |    fps                  | 854         |
# |    iterations           | 32          |
# |    time_elapsed         | 38          |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.004961824 |
# |    clip_fraction        | 0.0294      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.32       |
# |    explained_variance   | -0.00148    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.27e+05    |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.00588    |
# |    std                  | 1.02        |
# |    value_loss           | 2.73e+05    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 500         |
# |    ep_rew_mean          | -7.45e+03   |
# | time/                   |             |
# |    fps                  | 853         |
# |    iterations           | 33          |
# |    time_elapsed         | 39          |
# |    total_timesteps      | 33792       |
# | train/                  |             |
# |    approx_kl            | 0.003926551 |
# |    clip_fraction        | 0.0163      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.32       |
# |    explained_variance   | -6.78e-05   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.06e+05    |
# |    n_updates            | 320         |
# |    policy_gradient_loss | -0.00347    |
# |    std                  | 1.02        |
# |    value_loss           | 2.53e+05    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 493          |
# |    ep_rew_mean          | -7.38e+03    |
# | time/                   |              |
# |    fps                  | 853          |
# |    iterations           | 34           |
# |    time_elapsed         | 40           |
# |    total_timesteps      | 34816        |
# | train/                  |              |
# |    approx_kl            | 0.0045987554 |
# |    clip_fraction        | 0.0469       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.32        |
# |    explained_variance   | -1.14e-05    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.22e+05     |
# |    n_updates            | 330          |
# |    policy_gradient_loss | -0.00255     |
# |    std                  | 1.02         |
# |    value_loss           | 2.68e+05     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 494          |
# |    ep_rew_mean          | -7.36e+03    |
# | time/                   |              |
# |    fps                  | 854          |
# |    iterations           | 35           |
# |    time_elapsed         | 41           |
# |    total_timesteps      | 35840        |
# | train/                  |              |
# |    approx_kl            | 0.0030991659 |
# |    clip_fraction        | 0.00859      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.33        |
# |    explained_variance   | -0.0021      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.38e+05     |
# |    n_updates            | 340          |
# |    policy_gradient_loss | -0.00392     |
# |    std                  | 1.03         |
# |    value_loss           | 2.42e+05     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 494         |
# |    ep_rew_mean          | -7.37e+03   |
# | time/                   |             |
# |    fps                  | 854         |
# |    iterations           | 36          |
# |    time_elapsed         | 43          |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.018644061 |
# |    clip_fraction        | 0.0657      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.35       |
# |    explained_variance   | -1.91e-06   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.38e+05    |
# |    n_updates            | 350         |
# |    policy_gradient_loss | -0.00543    |
# |    std                  | 1.03        |
# |    value_loss           | 2.71e+05    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 494        |
# |    ep_rew_mean          | -7.39e+03  |
# | time/                   |            |
# |    fps                  | 853        |
# |    iterations           | 37         |
# |    time_elapsed         | 44         |
# |    total_timesteps      | 37888      |
# | train/                  |            |
# |    approx_kl            | 0.00504046 |
# |    clip_fraction        | 0.0326     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.33      |
# |    explained_variance   | 3.06e-05   |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.15e+05   |
# |    n_updates            | 360        |
# |    policy_gradient_loss | -0.00368   |
# |    std                  | 1.02       |
# |    value_loss           | 2.58e+05   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 494         |
# |    ep_rew_mean          | -7.4e+03    |
# | time/                   |             |
# |    fps                  | 854         |
# |    iterations           | 38          |
# |    time_elapsed         | 45          |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.003420094 |
# |    clip_fraction        | 0.00957     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.33       |
# |    explained_variance   | -0.0125     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.04e+05    |
# |    n_updates            | 370         |
# |    policy_gradient_loss | -0.00269    |
# |    std                  | 1.03        |
# |    value_loss           | 2.3e+05     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 494          |
# |    ep_rew_mean          | -7.4e+03     |
# | time/                   |              |
# |    fps                  | 854          |
# |    iterations           | 39           |
# |    time_elapsed         | 46           |
# |    total_timesteps      | 39936        |
# | train/                  |              |
# |    approx_kl            | 0.0045588464 |
# |    clip_fraction        | 0.0212       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.33        |
# |    explained_variance   | -0.000721    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.37e+04     |
# |    n_updates            | 380          |
# |    policy_gradient_loss | -0.00326     |
# |    std                  | 1.02         |
# |    value_loss           | 2.29e+05     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 494          |
# |    ep_rew_mean          | -7.38e+03    |
# | time/                   |              |
# |    fps                  | 854          |
# |    iterations           | 40           |
# |    time_elapsed         | 47           |
# |    total_timesteps      | 40960        |
# | train/                  |              |
# |    approx_kl            | 0.0039284183 |
# |    clip_fraction        | 0.0564       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.33        |
# |    explained_variance   | -0.000354    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 8.22e+04     |
# |    n_updates            | 390          |
# |    policy_gradient_loss | -0.0017      |
# |    std                  | 1.02         |
# |    value_loss           | 2.64e+05     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 494         |
# |    ep_rew_mean          | -7.41e+03   |
# | time/                   |             |
# |    fps                  | 853         |
# |    iterations           | 41          |
# |    time_elapsed         | 49          |
# |    total_timesteps      | 41984       |
# | train/                  |             |
# |    approx_kl            | 0.006175513 |
# |    clip_fraction        | 0.191       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.32       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.6e+05     |
# |    n_updates            | 400         |
# |    policy_gradient_loss | 0.00264     |
# |    std                  | 1.02        |
# |    value_loss           | 2.66e+05    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 495        |
# |    ep_rew_mean          | -7.38e+03  |
# | time/                   |            |
# |    fps                  | 854        |
# |    iterations           | 42         |
# |    time_elapsed         | 50         |
# |    total_timesteps      | 43008      |
# | train/                  |            |
# |    approx_kl            | 0.00467544 |
# |    clip_fraction        | 0.0248     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.32      |
# |    explained_variance   | -0.000121  |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.26e+05   |
# |    n_updates            | 410        |
# |    policy_gradient_loss | -0.00398   |
# |    std                  | 1.02       |
# |    value_loss           | 2.76e+05   |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 495          |
# |    ep_rew_mean          | -7.38e+03    |
# | time/                   |              |
# |    fps                  | 854          |
# |    iterations           | 43           |
# |    time_elapsed         | 51           |
# |    total_timesteps      | 44032        |
# | train/                  |              |
# |    approx_kl            | 0.0048640002 |
# |    clip_fraction        | 0.033        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.32        |
# |    explained_variance   | 9.54e-07     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.34e+05     |
# |    n_updates            | 420          |
# |    policy_gradient_loss | -0.00449     |
# |    std                  | 1.02         |
# |    value_loss           | 2.7e+05      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 495         |
# |    ep_rew_mean          | -7.39e+03   |
# | time/                   |             |
# |    fps                  | 854         |
# |    iterations           | 44          |
# |    time_elapsed         | 52          |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.004780152 |
# |    clip_fraction        | 0.0986      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.31       |
# |    explained_variance   | 1.79e-07    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.03e+05    |
# |    n_updates            | 430         |
# |    policy_gradient_loss | -0.00265    |
# |    std                  | 1.02        |
# |    value_loss           | 3.48e+05    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 495          |
# |    ep_rew_mean          | -7.39e+03    |
# | time/                   |              |
# |    fps                  | 854          |
# |    iterations           | 45           |
# |    time_elapsed         | 53           |
# |    total_timesteps      | 46080        |
# | train/                  |              |
# |    approx_kl            | 0.0052224174 |
# |    clip_fraction        | 0.0382       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.31        |
# |    explained_variance   | 6.56e-07     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.9e+05      |
# |    n_updates            | 440          |
# |    policy_gradient_loss | -0.00488     |
# |    std                  | 1.02         |
# |    value_loss           | 2.81e+05     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 495          |
# |    ep_rew_mean          | -7.4e+03     |
# | time/                   |              |
# |    fps                  | 854          |
# |    iterations           | 46           |
# |    time_elapsed         | 55           |
# |    total_timesteps      | 47104        |
# | train/                  |              |
# |    approx_kl            | 0.0058936663 |
# |    clip_fraction        | 0.0684       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.3         |
# |    explained_variance   | 1.55e-06     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.37e+05     |
# |    n_updates            | 450          |
# |    policy_gradient_loss | -0.00502     |
# |    std                  | 1.02         |
# |    value_loss           | 2.45e+05     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 494          |
# |    ep_rew_mean          | -7.41e+03    |
# | time/                   |              |
# |    fps                  | 853          |
# |    iterations           | 47           |
# |    time_elapsed         | 56           |
# |    total_timesteps      | 48128        |
# | train/                  |              |
# |    approx_kl            | 0.0060837446 |
# |    clip_fraction        | 0.0335       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.3         |
# |    explained_variance   | -0.000561    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.1e+05      |
# |    n_updates            | 460          |
# |    policy_gradient_loss | -0.00545     |
# |    std                  | 1.01         |
# |    value_loss           | 3.09e+05     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 490         |
# |    ep_rew_mean          | -7.41e+03   |
# | time/                   |             |
# |    fps                  | 853         |
# |    iterations           | 48          |
# |    time_elapsed         | 57          |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.005488637 |
# |    clip_fraction        | 0.0349      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.3        |
# |    explained_variance   | -2.38e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.02e+05    |
# |    n_updates            | 470         |
# |    policy_gradient_loss | -0.00428    |
# |    std                  | 1.02        |
# |    value_loss           | 3.44e+05    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 490         |
# |    ep_rew_mean          | -7.37e+03   |
# | time/                   |             |
# |    fps                  | 853         |
# |    iterations           | 49          |
# |    time_elapsed         | 58          |
# |    total_timesteps      | 50176       |
# | train/                  |             |
# |    approx_kl            | 0.005127053 |
# |    clip_fraction        | 0.0419      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.31       |
# |    explained_variance   | -3.22e-06   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.07e+05    |
# |    n_updates            | 480         |
# |    policy_gradient_loss | -0.00583    |
# |    std                  | 1.02        |
# |    value_loss           | 3.53e+05    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 490         |
# |    ep_rew_mean          | -7.36e+03   |
# | time/                   |             |
# |    fps                  | 852         |
# |    iterations           | 50          |
# |    time_elapsed         | 60          |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.005315394 |
# |    clip_fraction        | 0.0417      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.3        |
# |    explained_variance   | -3.58e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.02e+05    |
# |    n_updates            | 490         |
# |    policy_gradient_loss | -0.00597    |
# |    std                  | 1.01        |
# |    value_loss           | 1.39e+05    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 487         |
# |    ep_rew_mean          | -7.37e+03   |
# | time/                   |             |
# |    fps                  | 852         |
# |    iterations           | 51          |
# |    time_elapsed         | 61          |
# |    total_timesteps      | 52224       |
# | train/                  |             |
# |    approx_kl            | 0.005379621 |
# |    clip_fraction        | 0.0219      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.29       |
# |    explained_variance   | -4.77e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 9.25e+04    |
# |    n_updates            | 500         |
# |    policy_gradient_loss | -0.00454    |
# |    std                  | 1.01        |
# |    value_loss           | 2.28e+05    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 482          |
# |    ep_rew_mean          | -7.35e+03    |
# | time/                   |              |
# |    fps                  | 852          |
# |    iterations           | 52           |
# |    time_elapsed         | 62           |
# |    total_timesteps      | 53248        |
# | train/                  |              |
# |    approx_kl            | 0.0038359624 |
# |    clip_fraction        | 0.0127       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.29        |
# |    explained_variance   | -2.38e-06    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.12e+05     |
# |    n_updates            | 510          |
# |    policy_gradient_loss | -0.00473     |
# ...
# |    std                  | 0.795       |
# |    value_loss           | 644         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 68.6        |
# |    ep_rew_mean          | -132        |
# | time/                   |             |
# |    fps                  | 793         |
# |    iterations           | 180         |
# |    time_elapsed         | 232         |
# |    total_timesteps      | 184320      |
# | train/                  |             |
# |    approx_kl            | 0.007171888 |
# |    clip_fraction        | 0.105       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.55       |
# |    explained_variance   | 0.398       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 216         |
# |    n_updates            | 1790        |
# |    policy_gradient_loss | -0.00674    |
# |    std                  | 0.795       |
# |    value_loss           | 3.18e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 61.2        |
# |    ep_rew_mean          | -122        |
# | time/                   |             |
# |    fps                  | 793         |
# |    iterations           | 181         |
# |    time_elapsed         | 233         |
# |    total_timesteps      | 185344      |
# | train/                  |             |
# |    approx_kl            | 0.021033844 |
# |    clip_fraction        | 0.155       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.57       |
# |    explained_variance   | 0.301       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 95.7        |
# |    n_updates            | 1800        |
# |    policy_gradient_loss | -0.00147    |
# |    std                  | 0.803       |
# |    value_loss           | 624         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60.4         |
# |    ep_rew_mean          | -135         |
# | time/                   |              |
# |    fps                  | 792          |
# |    iterations           | 182          |
# |    time_elapsed         | 235          |
# |    total_timesteps      | 186368       |
# | train/                  |              |
# |    approx_kl            | 0.0047738594 |
# |    clip_fraction        | 0.101        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.57        |
# |    explained_variance   | -0.0886      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 615          |
# |    n_updates            | 1810         |
# |    policy_gradient_loss | -0.00923     |
# |    std                  | 0.798        |
# |    value_loss           | 804          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 64.4        |
# |    ep_rew_mean          | -145        |
# | time/                   |             |
# |    fps                  | 792         |
# |    iterations           | 183         |
# |    time_elapsed         | 236         |
# |    total_timesteps      | 187392      |
# | train/                  |             |
# |    approx_kl            | 0.003064431 |
# |    clip_fraction        | 0.0355      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.56       |
# |    explained_variance   | 0.136       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 9.9e+03     |
# |    n_updates            | 1820        |
# |    policy_gradient_loss | -0.00248    |
# |    std                  | 0.798       |
# |    value_loss           | 1.23e+04    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 57.1       |
# |    ep_rew_mean          | -139       |
# | time/                   |            |
# |    fps                  | 792        |
# |    iterations           | 184        |
# |    time_elapsed         | 237        |
# |    total_timesteps      | 188416     |
# | train/                  |            |
# |    approx_kl            | 0.03254457 |
# |    clip_fraction        | 0.187      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.56      |
# |    explained_variance   | 0.387      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 147        |
# |    n_updates            | 1830       |
# |    policy_gradient_loss | -0.014     |
# |    std                  | 0.794      |
# |    value_loss           | 556        |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 55           |
# |    ep_rew_mean          | -122         |
# | time/                   |              |
# |    fps                  | 791          |
# |    iterations           | 185          |
# |    time_elapsed         | 239          |
# |    total_timesteps      | 189440       |
# | train/                  |              |
# |    approx_kl            | 0.0051275874 |
# |    clip_fraction        | 0.0563       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.54        |
# |    explained_variance   | 0.284        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 831          |
# |    n_updates            | 1840         |
# |    policy_gradient_loss | -0.0033      |
# |    std                  | 0.789        |
# |    value_loss           | 1.01e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 55.5        |
# |    ep_rew_mean          | -132        |
# | time/                   |             |
# |    fps                  | 791         |
# |    iterations           | 186         |
# |    time_elapsed         | 240         |
# |    total_timesteps      | 190464      |
# | train/                  |             |
# |    approx_kl            | 0.006788878 |
# |    clip_fraction        | 0.11        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.52       |
# |    explained_variance   | 0.075       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 124         |
# |    n_updates            | 1850        |
# |    policy_gradient_loss | -0.00445    |
# |    std                  | 0.783       |
# |    value_loss           | 533         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 56.5        |
# |    ep_rew_mean          | -125        |
# | time/                   |             |
# |    fps                  | 790         |
# |    iterations           | 187         |
# |    time_elapsed         | 242         |
# |    total_timesteps      | 191488      |
# | train/                  |             |
# |    approx_kl            | 0.005326284 |
# |    clip_fraction        | 0.0923      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.5        |
# |    explained_variance   | 0.478       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 224         |
# |    n_updates            | 1860        |
# |    policy_gradient_loss | -0.00869    |
# |    std                  | 0.778       |
# |    value_loss           | 793         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 59           |
# |    ep_rew_mean          | -124         |
# | time/                   |              |
# |    fps                  | 790          |
# |    iterations           | 188          |
# |    time_elapsed         | 243          |
# |    total_timesteps      | 192512       |
# | train/                  |              |
# |    approx_kl            | 0.0074721063 |
# |    clip_fraction        | 0.123        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.49        |
# |    explained_variance   | 0.321        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 126          |
# |    n_updates            | 1870         |
# |    policy_gradient_loss | -0.00787     |
# |    std                  | 0.778        |
# |    value_loss           | 616          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 53.7        |
# |    ep_rew_mean          | -103        |
# | time/                   |             |
# |    fps                  | 790         |
# |    iterations           | 189         |
# |    time_elapsed         | 244         |
# |    total_timesteps      | 193536      |
# | train/                  |             |
# |    approx_kl            | 0.012323312 |
# |    clip_fraction        | 0.138       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.5        |
# |    explained_variance   | 0.156       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 119         |
# |    n_updates            | 1880        |
# |    policy_gradient_loss | -0.0016     |
# |    std                  | 0.779       |
# |    value_loss           | 717         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 54.7        |
# |    ep_rew_mean          | -106        |
# | time/                   |             |
# |    fps                  | 790         |
# |    iterations           | 190         |
# |    time_elapsed         | 246         |
# |    total_timesteps      | 194560      |
# | train/                  |             |
# |    approx_kl            | 0.010859506 |
# |    clip_fraction        | 0.123       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.49       |
# |    explained_variance   | 0.15        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 114         |
# |    n_updates            | 1890        |
# |    policy_gradient_loss | -0.00572    |
# |    std                  | 0.778       |
# |    value_loss           | 836         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 53.8         |
# |    ep_rew_mean          | -95          |
# | time/                   |              |
# |    fps                  | 790          |
# |    iterations           | 191          |
# |    time_elapsed         | 247          |
# |    total_timesteps      | 195584       |
# | train/                  |              |
# |    approx_kl            | 0.0082286885 |
# |    clip_fraction        | 0.153        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.5         |
# |    explained_variance   | 0.214        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 56.4         |
# |    n_updates            | 1900         |
# |    policy_gradient_loss | -0.00242     |
# |    std                  | 0.782        |
# |    value_loss           | 374          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 55           |
# |    ep_rew_mean          | -93.6        |
# | time/                   |              |
# |    fps                  | 789          |
# |    iterations           | 192          |
# |    time_elapsed         | 248          |
# |    total_timesteps      | 196608       |
# | train/                  |              |
# |    approx_kl            | 0.0060115866 |
# |    clip_fraction        | 0.103        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.51        |
# |    explained_variance   | 0.156        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 163          |
# |    n_updates            | 1910         |
# |    policy_gradient_loss | -0.009       |
# |    std                  | 0.784        |
# |    value_loss           | 543          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 54.5        |
# |    ep_rew_mean          | -89.8       |
# | time/                   |             |
# |    fps                  | 789         |
# |    iterations           | 193         |
# |    time_elapsed         | 250         |
# |    total_timesteps      | 197632      |
# | train/                  |             |
# |    approx_kl            | 0.011368314 |
# |    clip_fraction        | 0.0835      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.5        |
# |    explained_variance   | 0.343       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 126         |
# |    n_updates            | 1920        |
# |    policy_gradient_loss | -0.00319    |
# |    std                  | 0.779       |
# |    value_loss           | 561         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 57.2        |
# |    ep_rew_mean          | -105        |
# | time/                   |             |
# |    fps                  | 789         |
# |    iterations           | 194         |
# |    time_elapsed         | 251         |
# |    total_timesteps      | 198656      |
# | train/                  |             |
# |    approx_kl            | 0.012327865 |
# |    clip_fraction        | 0.11        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.49       |
# |    explained_variance   | 0.28        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 96.6        |
# |    n_updates            | 1930        |
# |    policy_gradient_loss | -0.00957    |
# |    std                  | 0.777       |
# |    value_loss           | 390         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 62.5        |
# |    ep_rew_mean          | -120        |
# | time/                   |             |
# |    fps                  | 789         |
# |    iterations           | 195         |
# |    time_elapsed         | 252         |
# |    total_timesteps      | 199680      |
# | train/                  |             |
# |    approx_kl            | 0.013081765 |
# |    clip_fraction        | 0.177       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.49       |
# |    explained_variance   | 0.314       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 583         |
# |    n_updates            | 1940        |
# |    policy_gradient_loss | -0.0122     |
# |    std                  | 0.776       |
# |    value_loss           | 1.03e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 62.2         |
# |    ep_rew_mean          | -119         |
# | time/                   |              |
# |    fps                  | 789          |
# |    iterations           | 196          |
# |    time_elapsed         | 254          |
# |    total_timesteps      | 200704       |
# | train/                  |              |
# |    approx_kl            | 0.0076265624 |
# |    clip_fraction        | 0.0712       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.49        |
# |    explained_variance   | 0.244        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 421          |
# |    n_updates            | 1950         |
# |    policy_gradient_loss | -0.00327     |
# |    std                  | 0.778        |
# |    value_loss           | 912          |
# ------------------------------------------
# Training done!

# %%
# reset env
obs, _ = env.reset()
crossing_history_ppo = [env.current_crossings]

print(f"Initial crossings: {env.current_crossings}")

# use trained model to run an episode
done = False
truncated = False
while not (done or truncated):
    action, _ = model.predict(obs, deterministic=True)
    obs, reward, done, truncated, info = env.step(action)
    crossing_history_ppo.append(info['crossings'])

print(f"Final crossings: {env.current_crossings}")
# Out:
# Initial crossings: 76.0
# Final crossings: 95.0

# %%
plt.figure(figsize=(10, 5))
plt.plot(crossing_history, label="Random Policy", alpha=0.7)
plt.plot(crossing_history_ppo, label="PPO", alpha=0.7)
plt.xlabel("Steps")
plt.ylabel("Edge Crossings")
plt.title("Random Policy vs PPO")
plt.legend()
plt.grid(True)
plt.show()
